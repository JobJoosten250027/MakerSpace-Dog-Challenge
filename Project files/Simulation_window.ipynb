# %% [markdown]
# **Opening a simulation window to actually show the robot**

# %%
#Installing required packages
# %pip install mujoco
# %pip install mujoco-python-viewer
# Out:
# Requirement already satisfied: mujoco in c:\users\job-j\anaconda3\lib\site-packages (3.4.0)
# Requirement already satisfied: absl-py in c:\users\job-j\anaconda3\lib\site-packages (from mujoco) (2.3.1)
# Requirement already satisfied: etils[epath] in c:\users\job-j\anaconda3\lib\site-packages (from mujoco) (1.13.0)
# Requirement already satisfied: glfw in c:\users\job-j\anaconda3\lib\site-packages (from mujoco) (2.10.0)
# Requirement already satisfied: numpy in c:\users\job-j\anaconda3\lib\site-packages (from mujoco) (2.1.3)
# Requirement already satisfied: pyopengl in c:\users\job-j\anaconda3\lib\site-packages (from mujoco) (3.1.10)
# Requirement already satisfied: fsspec in c:\users\job-j\anaconda3\lib\site-packages (from etils[epath]->mujoco) (2025.3.2)
# Requirement already satisfied: importlib_resources in c:\users\job-j\anaconda3\lib\site-packages (from etils[epath]->mujoco) (6.5.2)
# Requirement already satisfied: typing_extensions in c:\users\job-j\anaconda3\lib\site-packages (from etils[epath]->mujoco) (4.12.2)
# Requirement already satisfied: zipp in c:\users\job-j\anaconda3\lib\site-packages (from etils[epath]->mujoco) (3.21.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mujoco-python-viewer in c:\users\job-j\anaconda3\lib\site-packages (0.1.4)
# Requirement already satisfied: mujoco>=2.1.5 in c:\users\job-j\anaconda3\lib\site-packages (from mujoco-python-viewer) (3.4.0)
# Requirement already satisfied: glfw>=2.5.0 in c:\users\job-j\anaconda3\lib\site-packages (from mujoco-python-viewer) (2.10.0)
# Requirement already satisfied: imageio in c:\users\job-j\anaconda3\lib\site-packages (from mujoco-python-viewer) (2.37.0)
# Requirement already satisfied: pyyaml in c:\users\job-j\anaconda3\lib\site-packages (from mujoco-python-viewer) (6.0.2)
# Requirement already satisfied: absl-py in c:\users\job-j\anaconda3\lib\site-packages (from mujoco>=2.1.5->mujoco-python-viewer) (2.3.1)
# Requirement already satisfied: etils[epath] in c:\users\job-j\anaconda3\lib\site-packages (from mujoco>=2.1.5->mujoco-python-viewer) (1.13.0)
# Requirement already satisfied: numpy in c:\users\job-j\anaconda3\lib\site-packages (from mujoco>=2.1.5->mujoco-python-viewer) (2.1.3)
# Requirement already satisfied: pyopengl in c:\users\job-j\anaconda3\lib\site-packages (from mujoco>=2.1.5->mujoco-python-viewer) (3.1.10)
# Requirement already satisfied: fsspec in c:\users\job-j\anaconda3\lib\site-packages (from etils[epath]->mujoco>=2.1.5->mujoco-python-viewer) (2025.3.2)
# Requirement already satisfied: importlib_resources in c:\users\job-j\anaconda3\lib\site-packages (from etils[epath]->mujoco>=2.1.5->mujoco-python-viewer) (6.5.2)
# Requirement already satisfied: typing_extensions in c:\users\job-j\anaconda3\lib\site-packages (from etils[epath]->mujoco>=2.1.5->mujoco-python-viewer) (4.12.2)
# Requirement already satisfied: zipp in c:\users\job-j\anaconda3\lib\site-packages (from etils[epath]->mujoco>=2.1.5->mujoco-python-viewer) (3.21.0)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\job-j\anaconda3\lib\site-packages (from imageio->mujoco-python-viewer) (11.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing necessary parts

import mujoco
import mujoco_viewer
import numpy as np
import threading

print(f'Mujoco Version: {mujoco.mj_version}')
print(f'Numpy version: {np.version}')
# Out:
# Mujoco Version: <built-in method mj_version of pybind11_builtins.pybind11_detail_function_record_v1_msvc_md_mscver19 object at 0x000002CEECB97FB0>
# Numpy version: <module 'numpy.version' from 'c:\\Users\\job-j\\anaconda3\\Lib\\site-packages\\numpy\\version.py'>

# %%
#Loading of the Unitree GO2-W model
